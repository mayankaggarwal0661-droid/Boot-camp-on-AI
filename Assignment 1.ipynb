# %%
import pandas as pd
import numpy as np

# Create a list of random numbers
random_numbers = np.random.randint(1, 100, size=15).tolist()
print("Original list:", random_numbers)

# Convert to a pandas Series
s = pd.Series(random_numbers)

# Filter and print even numbers
even_numbers = s[s % 2 == 0]
print("Even numbers:", even_numbers.tolist())
# Out:
# Original list: [27, 50, 38, 91, 35, 41, 41, 94, 40, 25, 54, 6, 84, 38, 52]
# Even numbers: [50, 38, 94, 40, 54, 6, 84, 38, 52]

# %%
import pandas as pd

# Create a string
text = "Pandas makes data analysis easy"
print("Original string:", text)

# 1. Reverse the string (character by character)
reversed_string = text[::-1]
print("Reversed string:", reversed_string)

# 2. Reverse the order of words using pandas
words_series = pd.Series(text.split())
reversed_words = ' '.join(words_series[::-1])
print("Reversed words:", reversed_words)
# Out:
# Original string: Pandas makes data analysis easy
# Reversed string: ysae sisylana atad sekam sadnaP
# Reversed words: easy analysis data makes Pandas
