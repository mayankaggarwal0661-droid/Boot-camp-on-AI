# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting spacy
#   Downloading spacy-3.8.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.2 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (0.17.4)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in ./.local/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.11.12)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (12.6.0)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.25.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-8.0.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: httpx>=0.24.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (35.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 11.3 MB/s  0:00:03eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (260 kB)
# Downloading murmurhash-1.0.15-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (134 kB)
# Downloading preshed-3.0.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.0/869.0 kB 4.1 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.7 MB/s  0:00:00
# Downloading thinc-8.3.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.2 MB/s  0:00:00m394.0 MB/s eta 0:00:01
# Downloading blis-1.3.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 10.4 MB/s  0:00:01eta 0:00:01
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.25.0-py3-none-any.whl (66 kB)
# Downloading smart_open-8.0.1-py3-none-any.whl (73 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, weasel, thinc, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 12/15 [weasel]  WARNING: The script weasel is installed in '/home/304c926b-3e97-4d5e-a1e2-72c0cf48e0a8/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 14/15 [spacy]  WARNING: The script spacy is installed in '/home/304c926b-3e97-4d5e-a1e2-72c0cf48e0a8/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [spacy]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.25.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 smart-open-8.0.1 spacy-3.8.16 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.8 MB/s  0:00:01ta 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load spaCy's lightweight English core model (~12MB)
nlp = spacy.load("en_core_web_sm")

# Sample unstructured text input
raw_resume_text = """
Rahul Sharma is a Software Developer living in New Delhi. 
He worked at Google for 3 years starting from March 2021. 
Rahul graduated from Delhi University and has expertise in Python, Machine Learning and AWS.
"""

print("Processing text with spaCy...\n")
doc = nlp(raw_resume_text)

print("--- Extracted Named Entities ---")
# Extract entities like Persons, Organizations, Locations, and Dates
for ent in doc.ents:
  print(f"Entity: {ent.text:<20} | Type: {ent.label_:<10} ({spacy.explain(ent.label_)})")

print("\n--- Identified Keywords/Nouns ---")
# Extract key nouns/skills
nouns = [token.text for token in doc if token.pos_ in ["NOUN", "PROPN"]]
print("Key Nouns Found:", list(set(nouns)))
# Out:
# Processing text with spaCy...
#
# --- Extracted Named Entities ---
# Entity: Rahul Sharma         | Type: PERSON     (People, including fictional)
# Entity: Software             | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: New Delhi            | Type: GPE        (Countries, cities, states)
# Entity: Google               | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: 3 years              | Type: DATE       (Absolute or relative dates or periods)
# Entity: March 2021           | Type: DATE       (Absolute or relative dates or periods)
# Entity: Delhi University     | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: Python               | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: Machine Learning     | Type: PERSON     (People, including fictional)
#
# --- Identified Keywords/Nouns ---
# Key Nouns Found: ['expertise', 'Learning', 'Developer', 'years', 'Software', 'Machine', 'AWS', 'University', 'Google', 'Delhi', 'March', 'Sharma', 'Rahul', 'Python', 'New']
